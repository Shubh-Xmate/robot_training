# %%
#import pandas module
import pandas as pd
#read the csv file into a dataframe
df = pd.read_csv("csv_data/data1.csv")
df
# Out:
#       0  0.0002776664336271836  -18.8   1.0  -51.2  4414.002203495482  \
# 0     0               0.000309  -18.8   1.0  -50.6       -1987.041919
# 1     0               0.000343  -18.8   1.0  -50.0         564.033159
# 2     0               0.000381  -18.8   1.0  -49.4       -2611.667194
# 3     0               0.000423  -18.8   1.0  -48.8        5922.326899
# 4     0               0.000470  -18.8   1.0  -48.2        2099.518887
# ...  ..                    ...    ...   ...    ...                ...
# 4061  0               0.000000   65.7  13.8  -14.7        -293.373611
# 4062  0               0.000000   65.1  13.7  -14.9       -2263.558515
# 4063  0               0.000000   64.6  13.7  -15.1        1997.930515
# 4064  0               0.000000   64.0  13.7  -15.3       -2407.870138
# 4065  0               0.000000   63.4  13.7  -15.5       -2797.860420
#
#       3964.397019386156  -350.38778318411426  -17.774380355415673  \
# 0            621.955829          4141.466120          1658.309439
# 1             60.367029          2540.459695          1270.314337
# 2           3802.396883          1750.673479           802.939131
# 3           -801.801539         -1147.629349         -1067.156992
# 4          -2174.838674          -127.748623          1884.417503
# ...                 ...                  ...                  ...
# 4061       -1948.808070         -1972.391204          -559.493891
# 4062         505.016363           471.235139          -529.025935
# 4063       -3232.775866          -196.524207         -2308.170458
# 4064        -118.119780         -1024.865312            36.079477
# 4065         476.703008           286.875912          1329.418418
#
#       328.2914642474252  ...  51.50979031550348  -100.36620420485868  \
# 0             17.208462  ...        -117.495433          -229.873170
# 1            -73.606975  ...          87.826243          -121.265177
# 2           -296.684423  ...          75.587604           365.306140
# 3            669.745980  ...        -287.728230            47.432097
# 4           -257.133949  ...         105.704039           269.897129
# ...                 ...  ...                ...                  ...
# 4061         740.251296  ...        -117.529817          -108.707510
# 4062        -304.392562  ...         -33.742702          -128.685661
# 4063        -518.814111  ...          63.648718            71.981059
# 4064        -289.595730  ...         136.627389           293.399531
# 4065         296.955969  ...          86.003654           -93.168744
#
#       549.3598107686153  66.71458815340748  646.4244332891238  \
# 0            -81.835439         -71.042043         221.473713
# 1            -25.832071        -179.066234        -304.632943
# 2              0.685707         -90.507237         -51.911101
# 3           -401.130744        -276.031723         -94.467547
# 4           -157.744521         -45.533724        -103.980028
# ...                 ...                ...                ...
# 4061        -134.787398          15.091232         108.262197
# 4062         346.601898        -270.921694          79.147382
# 4063          20.777652          38.533734          79.013414
# 4064        -374.256875         380.474067          88.111878
# 4065         -20.959632        -288.163136        -103.255331
#
#       330.5307391198497  362.2420226039292  187.20081378721736  \
# 0            123.138362          41.513201           30.987634
# 1           -211.840262         -38.073109           92.001603
# 2           -153.521204           4.524412          115.515103
# 3           -129.526032        -138.525079           94.409320
# 4            107.092115         -37.596712          -91.924974
# ...                 ...                ...                 ...
# 4061         424.637735         114.823767         -200.240859
# 4062        -256.971637        -230.265233           78.546364
# 4063         -10.033168         -54.205497         -144.980637
# 4064        -121.289436         104.095701         -310.833655
# 4065         -67.685480        -287.888575          -57.388867
#
#       305.6468972622181  378.5162683341076
# 0            127.590154         202.715520
# 1             47.207682        -266.766929
# 2           -155.708406        -122.134859
# 3            277.922124         -25.955949
# 4            114.380507         104.398909
# ...                 ...                ...
# 4061         -62.532997        -420.548740
# 4062        -192.771004          82.891515
# 4063        -199.876168         -76.788435
# 4064         -25.952808        -373.826230
# 4065        -171.380375         -68.266200
#
# [4066 rows x 155 columns]

# %%
#import the modules
import os
import pandas as pd
#read the path
file_path = "csv_data"
#list all the files from the directory
file_list = os.listdir(file_path)
file_list
# Out:
# ['data2.csv', 'data1.csv', 'data3.csv', 'data4.csv']

# %%
#import the modules
import os
import pandas as pd
#read the path
cwd = os.path.abspath('')
#list all the files from the directory
file_list = os.listdir(cwd)
file_list
# Out:
# ['.ipynb_checkpoints',
#  'model2.ipynb',
#  'model.h5',
#  '.git',
#  'model1.ipynb',
#  'checking_file.ipynb',
#  'csv_data',
#  'basic_lstm.ipynb',
#  'file_merging_code.ipynb',
#  'model0.ipynb',
#  'Final_Model.ipynb']

# %%
#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# []
